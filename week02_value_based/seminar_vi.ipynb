# %% [markdown]
# ### Markov decision process
#
# This week's methods are all built to solve __M__arkov __D__ecision __P__rocesses. In the broadest sense, an MDP is defined by how it changes states and how rewards are computed.
#
# State transition is defined by $P(s' |s,a)$ - how likely are you to end at state $s'$ if you take action $a$ from state $s$. Now there's more than one way to define rewards, but we'll use $r(s,a,s')$ function for convenience.
#
# _This notebook is inspired by the awesome_ [CS294](https://github.com/berkeleydeeprlcourse/homework/blob/36a0b58261acde756abd55306fbe63df226bf62b/hw2/HW2.ipynb) _by Berkeley_

# %% [markdown]
# For starters, let's define a simple MDP from this picture:
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/a/ad/Markov_Decision_Process.svg" width="400px" alt="Diagram by Waldoalvarez via Wikimedia Commons, CC BY-SA 4.0"/>

# %%
import sys, os
if 'google.colab' in sys.modules and not os.path.exists('.setup_complete'):
    # !wget -q https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/setup_colab.sh -O- | bash
    # !wget -q https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/week02_value_based/mdp.py
    # !touch .setup_complete

# This code creates a virtual display to draw game images on.
# It will have no effect if your machine has a monitor.
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY")) == 0:
    # !bash ../xvfb start
    os.environ['DISPLAY'] = ':1'

# %%
transition_probs = {
    's0': {
        'a0': {'s0': 0.5, 's2': 0.5},
        'a1': {'s2': 1}
    },
    's1': {
        'a0': {'s0': 0.7, 's1': 0.1, 's2': 0.2},
        'a1': {'s1': 0.95, 's2': 0.05}
    },
    's2': {
        'a0': {'s0': 0.4, 's2': 0.6},
        'a1': {'s0': 0.3, 's1': 0.3, 's2': 0.4}
    }
}
rewards = {
    's1': {'a0': {'s0': +5}},
    's2': {'a1': {'s0': -1}}
}

from mdp import MDP
mdp = MDP(transition_probs, rewards, initial_state='s0')
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %% [markdown]
# We can now use MDP just as any other gym environment:

# %%
print('initial state =', mdp.reset())
next_state, reward, done, info = mdp.step('a1')
print('next_state = %s, reward = %s, done = %s' % (next_state, reward, done))

print('\n')

print('initial state =', mdp.reset())
next_state, reward, done, info = mdp.step('a0')
print('next_state = %s, reward = %s, done = %s' % (next_state, reward, done))
next_state, reward, done, info = mdp.step('a0')
print('next_state = %s, reward = %s, done = %s' % (next_state, reward, done))
# Out:
# initial state = s0
# next_state = s2, reward = 0.0, done = False
#
#
# initial state = s0
# next_state = s2, reward = 0.0, done = False
# next_state = s2, reward = 0.0, done = False

# %% [markdown]
# but it also has other methods that you'll need for Value Iteration

# %%
print("mdp.get_all_states =", mdp.get_all_states())
print("mdp.get_possible_actions('s1') = ", mdp.get_possible_actions('s1'))
print("mdp.get_next_states('s1', 'a0') = ", mdp.get_next_states('s1', 'a0'))
print("mdp.get_reward('s1', 'a0', 's0') = ", mdp.get_reward('s1', 'a0', 's0'))
print("mdp.get_transition_prob('s1', 'a0', 's0') = ", mdp.get_transition_prob('s1', 'a0', 's0'))
# Out:
# mdp.get_all_states = ('s0', 's1', 's2')
# mdp.get_possible_actions('s1') =  ('a0', 'a1')
# mdp.get_next_states('s1', 'a0') =  {'s0': 0.7, 's1': 0.1, 's2': 0.2}
# mdp.get_reward('s1', 'a0', 's0') =  5
# mdp.get_transition_prob('s1', 'a0', 's0') =  0.7

# %% [markdown]
# ### Optional: Visualizing MDPs
#
# You can also visualize any MDP with the drawing fuction donated by [neer201](https://github.com/neer201).
#
# You have to install graphviz for system and for python.
#
# 1. * For ubuntu just run: `sudo apt-get install graphviz`
#    * For OSX: `brew install graphviz`
# 2. `pip install graphviz`
# 3. restart the notebook
#
# __Note:__ Installing graphviz on some OS (esp. Windows) may be tricky. However, you can ignore this part alltogether and use the standart vizualization.

# %%
from mdp import has_graphviz
from IPython.display import display
print("Graphviz available:", has_graphviz)
# Out:
# Graphviz available: True

# %%
if has_graphviz:
    from mdp import plot_graph, plot_graph_with_state_values, plot_graph_optimal_strategy_and_state_values
    display(plot_graph(mdp))

# %% [markdown]
# ### Value Iteration
#
# Now let's build something to solve this MDP. The simplest algorithm so far is __V__alue __I__teration
#
# Here's the pseudo-code for VI:
#
# ---
#
# `1.` Initialize $V^{(0)}(s)=0$, for all $s$
#
# `2.` For $i=0, 1, 2, \dots$
#
# `3.` $ \quad V_{(i+1)}(s) = \max_a \sum_{s'} P(s' | s,a) \cdot [ r(s,a,s') + \gamma V_{i}(s')]$, for all $s$
#
# ---
#
# P(s' | s, a) — это:
# Вероятность того, что, находясь в состоянии s и выполнив действие a, мы окажемся в состоянии s'.

# %% [markdown]
# First, let's write a function to compute the state-action value function $Q^{\pi}$, defined as follows
#
# $$Q_i(s, a) = \sum_{s'} P(s' | s,a) \cdot [ r(s,a,s') + \gamma V_{i}(s')]$$

# %%
def get_action_value(mdp, state_values, state, action, gamma):
    """ Computes Q(s,a) as in formula above """

    # state - текущее состояние 
    # action - действие которое мы хотим сделать
    # gamma - коэффициент дисконтирования
    # state_values - это V_i(s')

    # мы находимя в состоянии s, нужно получить все состояния, куда мы можем прийти из этого s при действии a

    next_states = mdp.get_next_states(state, action) # map
    
    result = 0

    for key in next_states:
        reward = mdp.get_reward(state, action, key)
        result += next_states[key] * (reward + gamma * state_values[key])

    return result

# %%
import numpy as np
test_Vs = {s: i for i, s in enumerate(sorted(mdp.get_all_states()))}
assert np.isclose(get_action_value(mdp, test_Vs, 's2', 'a1', 0.9), 0.69)
assert np.isclose(get_action_value(mdp, test_Vs, 's1', 'a0', 0.9), 3.95)

# %% [markdown]
# Using $Q(s,a)$ we can now define the "next" V(s) for value iteration.
#  $$V_{(i+1)}(s) = \max_a \sum_{s'} P(s' | s,a) \cdot [ r(s,a,s') + \gamma V_{i}(s')] = \max_a Q_i(s,a)$$

# %%
def get_new_state_value(mdp, state_values, state, gamma):
    """ Computes next V(s) as in formula above. Please do not change state_values in process. """
    if mdp.is_terminal(state):
        return 0

    possible_actions = mdp.get_possible_actions(state)
    
    results = []

    for action in possible_actions:
        results.append(get_action_value(mdp, state_values, state, action, gamma))

    return max(results)

# %%
test_Vs_copy = dict(test_Vs)
assert np.isclose(get_new_state_value(mdp, test_Vs, 's0', 0.9), 1.8)
assert np.isclose(get_new_state_value(mdp, test_Vs, 's2', 0.9), 1.08)
assert np.isclose(get_new_state_value(mdp, {'s0': -1e10, 's1': 0, 's2': -2e10}, 's0', 0.9), -13500000000.0), \
    "Please ensure that you handle negative Q-values of arbitrary magnitude correctly"
assert test_Vs == test_Vs_copy, "Please do not change state_values in get_new_state_value"

# %% [markdown]
# Finally, let's combine everything we wrote into a working value iteration algo.

# %%
# parameters
gamma = 0.9            # discount for MDP
num_iter = 100         # maximum iterations, excluding initialization
# stop VI if new values are this close to old values (or closer)
min_difference = 0.001

# initialize V(s)
state_values = {s: 0 for s in mdp.get_all_states()}

if has_graphviz:
    display(plot_graph_with_state_values(mdp, state_values))

for i in range(num_iter):

    # Compute new state values using the functions you defined above.
    # It must be a dict {state : float V_new(state)}
    new_state_values = {state: get_new_state_value(mdp, state_values, state, gamma) for state in state_values}

    assert isinstance(new_state_values, dict)

    # Compute difference
    diff = max(abs(new_state_values[s] - state_values[s])
               for s in mdp.get_all_states())
    print("iter %4i   |   diff: %6.5f   |   " % (i, diff), end="")
    print('   '.join("V(%s) = %.3f" % (s, v) for s, v in state_values.items()))
    state_values = new_state_values

    if diff < min_difference:
        print("Terminated")
        break
# Out:
# iter    0   |   diff: 3.50000   |   V(s0) = 0.000   V(s1) = 0.000   V(s2) = 0.000
# iter    1   |   diff: 0.64500   |   V(s0) = 0.000   V(s1) = 3.500   V(s2) = 0.000
# iter    2   |   diff: 0.58050   |   V(s0) = 0.000   V(s1) = 3.815   V(s2) = 0.645
# iter    3   |   diff: 0.43582   |   V(s0) = 0.581   V(s1) = 3.959   V(s2) = 0.962
# iter    4   |   diff: 0.30634   |   V(s0) = 0.866   V(s1) = 4.395   V(s2) = 1.272
# iter    5   |   diff: 0.27571   |   V(s0) = 1.145   V(s1) = 4.670   V(s2) = 1.579
# iter    6   |   diff: 0.24347   |   V(s0) = 1.421   V(s1) = 4.926   V(s2) = 1.838
# iter    7   |   diff: 0.21419   |   V(s0) = 1.655   V(s1) = 5.169   V(s2) = 2.075
# iter    8   |   diff: 0.19277   |   V(s0) = 1.868   V(s1) = 5.381   V(s2) = 2.290
# iter    9   |   diff: 0.17327   |   V(s0) = 2.061   V(s1) = 5.573   V(s2) = 2.481
# iter   10   |   diff: 0.15569   |   V(s0) = 2.233   V(s1) = 5.746   V(s2) = 2.654
# iter   11   |   diff: 0.14012   |   V(s0) = 2.389   V(s1) = 5.902   V(s2) = 2.810
# iter   12   |   diff: 0.12610   |   V(s0) = 2.529   V(s1) = 6.042   V(s2) = 2.950
# iter   13   |   diff: 0.11348   |   V(s0) = 2.655   V(s1) = 6.168   V(s2) = 3.076
# iter   14   |   diff: 0.10213   |   V(s0) = 2.769   V(s1) = 6.282   V(s2) = 3.190
# iter   15   |   diff: 0.09192   |   V(s0) = 2.871   V(s1) = 6.384   V(s2) = 3.292
# iter   16   |   diff: 0.08272   |   V(s0) = 2.963   V(s1) = 6.476   V(s2) = 3.384
# iter   17   |   diff: 0.07445   |   V(s0) = 3.045   V(s1) = 6.558   V(s2) = 3.467
# iter   18   |   diff: 0.06701   |   V(s0) = 3.120   V(s1) = 6.633   V(s2) = 3.541
# iter   19   |   diff: 0.06031   |   V(s0) = 3.187   V(s1) = 6.700   V(s2) = 3.608
# iter   20   |   diff: 0.05428   |   V(s0) = 3.247   V(s1) = 6.760   V(s2) = 3.668
# iter   21   |   diff: 0.04885   |   V(s0) = 3.301   V(s1) = 6.814   V(s2) = 3.723
# iter   22   |   diff: 0.04396   |   V(s0) = 3.350   V(s1) = 6.863   V(s2) = 3.771
# iter   23   |   diff: 0.03957   |   V(s0) = 3.394   V(s1) = 6.907   V(s2) = 3.815
# iter   24   |   diff: 0.03561   |   V(s0) = 3.434   V(s1) = 6.947   V(s2) = 3.855
# iter   25   |   diff: 0.03205   |   V(s0) = 3.469   V(s1) = 6.982   V(s2) = 3.891
# iter   26   |   diff: 0.02884   |   V(s0) = 3.502   V(s1) = 7.014   V(s2) = 3.923
# iter   27   |   diff: 0.02596   |   V(s0) = 3.530   V(s1) = 7.043   V(s2) = 3.951
# iter   28   |   diff: 0.02336   |   V(s0) = 3.556   V(s1) = 7.069   V(s2) = 3.977
# iter   29   |   diff: 0.02103   |   V(s0) = 3.580   V(s1) = 7.093   V(s2) = 4.001
# iter   30   |   diff: 0.01892   |   V(s0) = 3.601   V(s1) = 7.114   V(s2) = 4.022
# iter   31   |   diff: 0.01703   |   V(s0) = 3.620   V(s1) = 7.133   V(s2) = 4.041
# iter   32   |   diff: 0.01533   |   V(s0) = 3.637   V(s1) = 7.150   V(s2) = 4.058
# iter   33   |   diff: 0.01380   |   V(s0) = 3.652   V(s1) = 7.165   V(s2) = 4.073
# iter   34   |   diff: 0.01242   |   V(s0) = 3.666   V(s1) = 7.179   V(s2) = 4.087
# iter   35   |   diff: 0.01117   |   V(s0) = 3.678   V(s1) = 7.191   V(s2) = 4.099
# iter   36   |   diff: 0.01006   |   V(s0) = 3.689   V(s1) = 7.202   V(s2) = 4.110
# iter   37   |   diff: 0.00905   |   V(s0) = 3.699   V(s1) = 7.212   V(s2) = 4.121
# iter   38   |   diff: 0.00815   |   V(s0) = 3.708   V(s1) = 7.221   V(s2) = 4.130
# iter   39   |   diff: 0.00733   |   V(s0) = 3.717   V(s1) = 7.230   V(s2) = 4.138
# iter   40   |   diff: 0.00660   |   V(s0) = 3.724   V(s1) = 7.237   V(s2) = 4.145
# iter   41   |   diff: 0.00594   |   V(s0) = 3.731   V(s1) = 7.244   V(s2) = 4.152
# iter   42   |   diff: 0.00534   |   V(s0) = 3.736   V(s1) = 7.249   V(s2) = 4.158
# iter   43   |   diff: 0.00481   |   V(s0) = 3.742   V(s1) = 7.255   V(s2) = 4.163
# iter   44   |   diff: 0.00433   |   V(s0) = 3.747   V(s1) = 7.260   V(s2) = 4.168
# iter   45   |   diff: 0.00390   |   V(s0) = 3.751   V(s1) = 7.264   V(s2) = 4.172
# iter   46   |   diff: 0.00351   |   V(s0) = 3.755   V(s1) = 7.268   V(s2) = 4.176
# iter   47   |   diff: 0.00316   |   V(s0) = 3.758   V(s1) = 7.271   V(s2) = 4.179
# iter   48   |   diff: 0.00284   |   V(s0) = 3.762   V(s1) = 7.275   V(s2) = 4.183
# iter   49   |   diff: 0.00256   |   V(s0) = 3.764   V(s1) = 7.277   V(s2) = 4.185
# iter   50   |   diff: 0.00230   |   V(s0) = 3.767   V(s1) = 7.280   V(s2) = 4.188
# iter   51   |   diff: 0.00207   |   V(s0) = 3.769   V(s1) = 7.282   V(s2) = 4.190
# iter   52   |   diff: 0.00186   |   V(s0) = 3.771   V(s1) = 7.284   V(s2) = 4.192
# iter   53   |   diff: 0.00168   |   V(s0) = 3.773   V(s1) = 7.286   V(s2) = 4.194
# iter   54   |   diff: 0.00151   |   V(s0) = 3.775   V(s1) = 7.288   V(s2) = 4.196
# iter   55   |   diff: 0.00136   |   V(s0) = 3.776   V(s1) = 7.289   V(s2) = 4.197
# iter   56   |   diff: 0.00122   |   V(s0) = 3.778   V(s1) = 7.291   V(s2) = 4.199
# iter   57   |   diff: 0.00110   |   V(s0) = 3.779   V(s1) = 7.292   V(s2) = 4.200
# iter   58   |   diff: 0.00099   |   V(s0) = 3.780   V(s1) = 7.293   V(s2) = 4.201
# Terminated

# %%
if has_graphviz:
    display(plot_graph_with_state_values(mdp, state_values))

# %%
print("Final state values:", state_values)

assert abs(state_values['s0'] - 3.781) < 0.01
assert abs(state_values['s1'] - 7.294) < 0.01
assert abs(state_values['s2'] - 4.202) < 0.01
# Out:
# Final state values: {'s0': 3.7810348735476405, 's1': 7.294006423867229, 's2': 4.202140275227048}

# %% [markdown]
# Now let's use those $V^{*}(s)$ to find optimal actions in each state
#
#  $$\pi^*(s) = argmax_a \sum_{s'} P(s' | s,a) \cdot [ r(s,a,s') + \gamma V_{i}(s')] = argmax_a Q_i(s,a)$$
#
# The only difference vs V(s) is that here we take not max but argmax: find action such with maximum Q(s,a).

# %%
def get_optimal_action(mdp, state_values, state, gamma=0.9):
    """ Finds optimal action using formula above. """
    if mdp.is_terminal(state):
        return None

    possible_actions = mdp.get_possible_actions(state)
    
    results = [] # q_values

    for action in possible_actions:
        results.append(get_action_value(mdp, state_values, state, action, gamma))

    return possible_actions[np.argmax(results)]

# %%
assert get_optimal_action(mdp, state_values, 's0', gamma) == 'a1'
assert get_optimal_action(mdp, state_values, 's1', gamma) == 'a0'
assert get_optimal_action(mdp, state_values, 's2', gamma) == 'a1'

assert get_optimal_action(mdp, {'s0': -1e10, 's1': 0, 's2': -2e10}, 's0', 0.9) == 'a0', \
    "Please ensure that you handle negative Q-values of arbitrary magnitude correctly"
assert get_optimal_action(mdp, {'s0': -2e10, 's1': 0, 's2': -1e10}, 's0', 0.9) == 'a1', \
    "Please ensure that you handle negative Q-values of arbitrary magnitude correctly"

# %%
if has_graphviz:
    display(plot_graph_optimal_strategy_and_state_values(mdp, state_values, get_action_value))

# %%
# Measure agent's average reward

s = mdp.reset()
rewards = []
for _ in range(10000):
    s, r, done, _ = mdp.step(get_optimal_action(mdp, state_values, s, gamma))
    rewards.append(r)

print("average reward: ", np.mean(rewards))

assert(0.40 < np.mean(rewards) < 0.55)
# Out:
# average reward:  0.4829

# %% [markdown]
# ### Frozen lake

# %%
from mdp import FrozenLakeEnv
mdp = FrozenLakeEnv(slip_chance=0)

mdp.render()
# Out:
# *FFF
# FHFH
# FFFH
# HFFG

# %%
def value_iteration(mdp, state_values=None, gamma=0.9, num_iter=1000, min_difference=1e-5):
    """ performs num_iter value iteration steps starting from state_values. Same as before but in a function """
    state_values = state_values or {s: 0 for s in mdp.get_all_states()}
    for i in range(num_iter):

        # Compute new state values using the functions you defined above. It must be a dict {state : new_V(state)}
        new_state_values = {state: get_new_state_value(mdp, state_values, state, gamma) for state in state_values}

        assert isinstance(new_state_values, dict)

        # Compute difference
        diff = max(abs(new_state_values[s] - state_values[s])
                   for s in mdp.get_all_states())

        print("iter %4i   |   diff: %6.5f   |   V(start): %.3f " %
              (i, diff, new_state_values[mdp._initial_state]))

        state_values = new_state_values
        if diff < min_difference:
            break

    return state_values

# %%
state_values = value_iteration(mdp)
# Out:
# iter    0   |   diff: 1.00000   |   V(start): 0.000
# iter    1   |   diff: 0.90000   |   V(start): 0.000
# iter    2   |   diff: 0.81000   |   V(start): 0.000
# iter    3   |   diff: 0.72900   |   V(start): 0.000
# iter    4   |   diff: 0.65610   |   V(start): 0.000
# iter    5   |   diff: 0.59049   |   V(start): 0.590
# iter    6   |   diff: 0.00000   |   V(start): 0.590

# %%
s = mdp.reset()
mdp.render()
for t in range(100):
    a = get_optimal_action(mdp, state_values, s, gamma)
    print(a, end='\n\n')
    s, r, done, _ = mdp.step(a)
    mdp.render()
    if done:
        break
# Out:
# *FFF
# FHFH
# FFFH
# HFFG
#
# down
#
# SFFF
# *HFH
# FFFH
# HFFG
#
# down
#
# SFFF
# FHFH
# *FFH
# HFFG
#
# right
#
# SFFF
# FHFH
# F*FH
# HFFG
#
# down
#
# SFFF
# FHFH
# FFFH
# H*FG
#
# right
#
# SFFF
# FHFH
# FFFH
# HF*G
#
# right
#
# SFFF
# FHFH
# FFFH
# HFF*

# %% [markdown]
# ### Let's visualize!
#
# It's usually interesting to see what your algorithm actually learned under the hood. To do so, we'll plot state value functions and optimal actions at each VI step.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline


def draw_policy(mdp, state_values):
    plt.figure(figsize=(3, 3))
    h, w = mdp.desc.shape
    states = sorted(mdp.get_all_states())
    V = np.array([state_values[s] for s in states])
    Pi = {s: get_optimal_action(mdp, state_values, s, gamma) for s in states}
    plt.imshow(V.reshape(w, h), cmap='gray', interpolation='none', clim=(0, 1))
    ax = plt.gca()
    ax.set_xticks(np.arange(h)-.5)
    ax.set_yticks(np.arange(w)-.5)
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    Y, X = np.mgrid[0:4, 0:4]
    a2uv = {'left': (-1, 0), 'down': (0, -1), 'right': (1, 0), 'up': (0, 1)}
    for y in range(h):
        for x in range(w):
            plt.text(x, y, str(mdp.desc[y, x].item()),
                     color='g', size=12,  verticalalignment='center',
                     horizontalalignment='center', fontweight='bold')
            a = Pi[y, x]
            if a is None:
                continue
            u, v = a2uv[a]
            plt.arrow(x, y, u*.3, -v*.3, color='m',
                      head_width=0.1, head_length=0.1)
    plt.grid(color='b', lw=2, ls='-')
    plt.show()

# %%
state_values = {s: 0 for s in mdp.get_all_states()}

for i in range(10):
    print("after iteration %i" % i)
    state_values = value_iteration(mdp, state_values, num_iter=1)
    draw_policy(mdp, state_values)
# please ignore iter 0 at each step
# Out:
# after iteration 0
# iter    0   |   diff: 1.00000   |   V(start): 0.000
# after iteration 1
# iter    0   |   diff: 0.90000   |   V(start): 0.000
# after iteration 2
# iter    0   |   diff: 0.81000   |   V(start): 0.000
# after iteration 3
# iter    0   |   diff: 0.72900   |   V(start): 0.000
# after iteration 4
# iter    0   |   diff: 0.65610   |   V(start): 0.000
# after iteration 5
# iter    0   |   diff: 0.59049   |   V(start): 0.590
# after iteration 6
# iter    0   |   diff: 0.00000   |   V(start): 0.590
# after iteration 7
# iter    0   |   diff: 0.00000   |   V(start): 0.590
# after iteration 8
# iter    0   |   diff: 0.00000   |   V(start): 0.590
# after iteration 9
# iter    0   |   diff: 0.00000   |   V(start): 0.590

# %%
from IPython.display import clear_output
from time import sleep
mdp = FrozenLakeEnv(map_name='8x8', slip_chance=0.1)
state_values = {s: 0 for s in mdp.get_all_states()}

for i in range(30):
    clear_output(True)
    print("after iteration %i" % i)
    state_values = value_iteration(mdp, state_values, num_iter=1)
    draw_policy(mdp, state_values)
    sleep(0.5)
# please ignore iter 0 at each step
# Out:
# after iteration 29
# iter    0   |   diff: 0.00000   |   V(start): 0.198

# %% [markdown]
# Massive tests

# %%
mdp = FrozenLakeEnv(slip_chance=0)
state_values = value_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    rewards = []
    for t in range(100):
        s, r, done, _ = mdp.step(
            get_optimal_action(mdp, state_values, s, gamma))
        rewards.append(r)
        if done:
            break
    total_rewards.append(np.sum(rewards))

print("average reward: ", np.mean(total_rewards))
assert(1.0 <= np.mean(total_rewards) <= 1.0)
print("Well done!")
# Out:
# iter    0   |   diff: 1.00000   |   V(start): 0.000
# iter    1   |   diff: 0.90000   |   V(start): 0.000
# iter    2   |   diff: 0.81000   |   V(start): 0.000
# iter    3   |   diff: 0.72900   |   V(start): 0.000
# iter    4   |   diff: 0.65610   |   V(start): 0.000
# iter    5   |   diff: 0.59049   |   V(start): 0.590
# iter    6   |   diff: 0.00000   |   V(start): 0.590
# average reward:  1.0
# Well done!

# %%
# Measure agent's average reward
mdp = FrozenLakeEnv(slip_chance=0.1)
state_values = value_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    rewards = []
    for t in range(100):
        s, r, done, _ = mdp.step(
            get_optimal_action(mdp, state_values, s, gamma))
        rewards.append(r)
        if done:
            break
    total_rewards.append(np.sum(rewards))

print("average reward: ", np.mean(total_rewards))
assert(0.8 <= np.mean(total_rewards) <= 0.95)
print("Well done!")
# Out:
# iter    0   |   diff: 0.90000   |   V(start): 0.000
# iter    1   |   diff: 0.72900   |   V(start): 0.000
# iter    2   |   diff: 0.62330   |   V(start): 0.000
# iter    3   |   diff: 0.50487   |   V(start): 0.000
# iter    4   |   diff: 0.40894   |   V(start): 0.000
# iter    5   |   diff: 0.34868   |   V(start): 0.349
# iter    6   |   diff: 0.06529   |   V(start): 0.410
# iter    7   |   diff: 0.05832   |   V(start): 0.468
# iter    8   |   diff: 0.01139   |   V(start): 0.480
# iter    9   |   diff: 0.00764   |   V(start): 0.487
# iter   10   |   diff: 0.00164   |   V(start): 0.489
# iter   11   |   diff: 0.00094   |   V(start): 0.490
# iter   12   |   diff: 0.00022   |   V(start): 0.490
# iter   13   |   diff: 0.00011   |   V(start): 0.490
# iter   14   |   diff: 0.00003   |   V(start): 0.490
# iter   15   |   diff: 0.00001   |   V(start): 0.490
# iter   16   |   diff: 0.00000   |   V(start): 0.490
# average reward:  0.875
# Well done!

# %%
# Measure agent's average reward
mdp = FrozenLakeEnv(slip_chance=0.25)
state_values = value_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    rewards = []
    for t in range(100):
        s, r, done, _ = mdp.step(
            get_optimal_action(mdp, state_values, s, gamma))
        rewards.append(r)
        if done:
            break
    total_rewards.append(np.sum(rewards))

print("average reward: ", np.mean(total_rewards))
assert(0.6 <= np.mean(total_rewards) <= 0.7)
print("Well done!")
# Out:
# iter    0   |   diff: 0.75000   |   V(start): 0.000
# iter    1   |   diff: 0.50625   |   V(start): 0.000
# iter    2   |   diff: 0.39867   |   V(start): 0.000
# iter    3   |   diff: 0.26910   |   V(start): 0.000
# iter    4   |   diff: 0.18164   |   V(start): 0.000
# iter    5   |   diff: 0.14013   |   V(start): 0.140
# iter    6   |   diff: 0.07028   |   V(start): 0.199
# iter    7   |   diff: 0.06030   |   V(start): 0.260
# iter    8   |   diff: 0.02594   |   V(start): 0.285
# iter    9   |   diff: 0.01918   |   V(start): 0.305
# iter   10   |   diff: 0.00858   |   V(start): 0.313
# iter   11   |   diff: 0.00560   |   V(start): 0.319
# iter   12   |   diff: 0.00260   |   V(start): 0.321
# iter   13   |   diff: 0.00159   |   V(start): 0.323
# iter   14   |   diff: 0.00076   |   V(start): 0.324
# iter   15   |   diff: 0.00045   |   V(start): 0.324
# iter   16   |   diff: 0.00022   |   V(start): 0.324
# iter   17   |   diff: 0.00012   |   V(start): 0.325
# iter   18   |   diff: 0.00006   |   V(start): 0.325
# iter   19   |   diff: 0.00003   |   V(start): 0.325
# iter   20   |   diff: 0.00002   |   V(start): 0.325
# iter   21   |   diff: 0.00001   |   V(start): 0.325
# average reward:  0.671
# Well done!

# %%
# Measure agent's average reward
mdp = FrozenLakeEnv(slip_chance=0.2, map_name='8x8')
state_values = value_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    rewards = []
    for t in range(100):
        s, r, done, _ = mdp.step(
            get_optimal_action(mdp, state_values, s, gamma))
        rewards.append(r)
        if done:
            break
    total_rewards.append(np.sum(rewards))

print("average reward: ", np.mean(total_rewards))
assert(0.6 <= np.mean(total_rewards) <= 0.8)
print("Well done!")
# Out:
# iter    0   |   diff: 0.80000   |   V(start): 0.000
# iter    1   |   diff: 0.57600   |   V(start): 0.000
# iter    2   |   diff: 0.41472   |   V(start): 0.000
# iter    3   |   diff: 0.29860   |   V(start): 0.000
# iter    4   |   diff: 0.24186   |   V(start): 0.000
# iter    5   |   diff: 0.19349   |   V(start): 0.000
# iter    6   |   diff: 0.15325   |   V(start): 0.000
# iter    7   |   diff: 0.12288   |   V(start): 0.000
# iter    8   |   diff: 0.09930   |   V(start): 0.000
# iter    9   |   diff: 0.08037   |   V(start): 0.000
# iter   10   |   diff: 0.06426   |   V(start): 0.000
# iter   11   |   diff: 0.05129   |   V(start): 0.000
# iter   12   |   diff: 0.04330   |   V(start): 0.000
# iter   13   |   diff: 0.03802   |   V(start): 0.033
# iter   14   |   diff: 0.03332   |   V(start): 0.058
# iter   15   |   diff: 0.02910   |   V(start): 0.087
# iter   16   |   diff: 0.01855   |   V(start): 0.106
# iter   17   |   diff: 0.01403   |   V(start): 0.120
# iter   18   |   diff: 0.00810   |   V(start): 0.128
# iter   19   |   diff: 0.00555   |   V(start): 0.133
# iter   20   |   diff: 0.00321   |   V(start): 0.137
# iter   21   |   diff: 0.00247   |   V(start): 0.138
# iter   22   |   diff: 0.00147   |   V(start): 0.139
# iter   23   |   diff: 0.00104   |   V(start): 0.140
# iter   24   |   diff: 0.00058   |   V(start): 0.140
# iter   25   |   diff: 0.00036   |   V(start): 0.141
# iter   26   |   diff: 0.00024   |   V(start): 0.141
# iter   27   |   diff: 0.00018   |   V(start): 0.141
# iter   28   |   diff: 0.00012   |   V(start): 0.141
# iter   29   |   diff: 0.00007   |   V(start): 0.141
# iter   30   |   diff: 0.00004   |   V(start): 0.141
# iter   31   |   diff: 0.00003   |   V(start): 0.141
# iter   32   |   diff: 0.00001   |   V(start): 0.141
# iter   33   |   diff: 0.00001   |   V(start): 0.141
# average reward:  0.761
# Well done!

# %% [markdown]
# # HW Part 1: Value iteration convergence
#
# ### Find an MDP for which value iteration takes long to converge  (1 pts)
#
# When we ran value iteration on the small frozen lake problem, the last iteration where an action changed was iteration 6--i.e., value iteration computed the optimal policy at iteration 6. Are there any guarantees regarding how many iterations it'll take value iteration to compute the optimal policy? There are no such guarantees without additional assumptions--we can construct the MDP in such a way that the greedy policy will change after arbitrarily many iterations.
#
# Your task: define an MDP with at most 3 states and 2 actions, such that when you run value iteration, the optimal action changes at iteration >= 50. Use discount=0.95. (However, note that the discount doesn't matter here--you can construct an appropriate MDP with any discount.)
#
# Note: value function must change at least once after iteration >=50, not necessarily change on every iteration till >=50.

# %%
transition_probs = {
    's0': {
        'a0': {'s1': 1.0},
        'a1': {'s2': 1.0}
    },
    's1': {
        'a0': {'s1': 1.0},
        'a1': {'s1': 1.0}
    },
    's2': {
        'a0': {'s2': 1.0},
        'a1': {'s2': 1.0}
    }
}

rewards = {
    's0': {
        'a0': {'s1': 0},
        'a1': {'s2': 0.76}
    },
    's1': {
        'a0': {'s1': 0.042},
        'a1': {'s1': 0.042}
    },
    's2': {
        'a0': {'s2': 0},
        'a1': {'s2': 0}
    }
}

from mdp import MDP
from numpy import random
mdp = MDP(transition_probs, rewards, initial_state=random.choice(tuple(transition_probs.keys())))
# Feel free to change the initial_state

# %%
gamma = 0.95
state_values = {s: 0 for s in mdp.get_all_states()}
policy = np.array([get_optimal_action(mdp, state_values, state, gamma)
                   for state in sorted(mdp.get_all_states())])

for i in range(100):
    print("after iteration %i" % i)
    state_values = value_iteration(mdp, state_values, gamma, num_iter=1)

    new_policy = np.array([get_optimal_action(mdp, state_values, state, gamma)
                           for state in sorted(mdp.get_all_states())])

    n_changes = (policy != new_policy).sum()
    print("N actions changed = %i \n" % n_changes)
    if (n_changes > 0):
        print("non zero")
        break
    policy = new_policy

# please ignore iter 0 at each step
# Out:
# after iteration 0
# iter    0   |   diff: 0.76000   |   V(start): 0.042
# N actions changed = 0
#
# after iteration 1
# iter    0   |   diff: 0.03990   |   V(start): 0.082
# N actions changed = 0
#
# after iteration 2
# iter    0   |   diff: 0.03790   |   V(start): 0.120
# N actions changed = 0
#
# after iteration 3
# iter    0   |   diff: 0.03601   |   V(start): 0.156
# N actions changed = 0
#
# after iteration 4
# iter    0   |   diff: 0.03421   |   V(start): 0.190
# N actions changed = 0
#
# after iteration 5
# iter    0   |   diff: 0.03250   |   V(start): 0.223
# N actions changed = 0
#
# after iteration 6
# iter    0   |   diff: 0.03087   |   V(start): 0.253
# N actions changed = 0
#
# after iteration 7
# iter    0   |   diff: 0.02933   |   V(start): 0.283
# N actions changed = 0
#
# after iteration 8
# iter    0   |   diff: 0.02786   |   V(start): 0.311
# N actions changed = 0
#
# after iteration 9
# iter    0   |   diff: 0.02647   |   V(start): 0.337
# N actions changed = 0
#
# after iteration 10
# iter    0   |   diff: 0.02515   |   V(start): 0.362
# N actions changed = 0
#
# after iteration 11
# iter    0   |   diff: 0.02389   |   V(start): 0.386
# N actions changed = 0
#
# after iteration 12
# iter    0   |   diff: 0.02270   |   V(start): 0.409
# N actions changed = 0
#
# after iteration 13
# iter    0   |   diff: 0.02156   |   V(start): 0.430
# N actions changed = 0
#
# after iteration 14
# iter    0   |   diff: 0.02048   |   V(start): 0.451
# N actions changed = 0
#
# after iteration 15
# iter    0   |   diff: 0.01946   |   V(start): 0.470
# N actions changed = 0
#
# after iteration 16
# iter    0   |   diff: 0.01849   |   V(start): 0.489
# N actions changed = 0
#
# after iteration 17
# iter    0   |   diff: 0.01756   |   V(start): 0.506
# N actions changed = 0
#
# after iteration 18
# iter    0   |   diff: 0.01668   |   V(start): 0.523
# N actions changed = 0
#
# after iteration 19
# iter    0   |   diff: 0.01585   |   V(start): 0.539
# N actions changed = 0
#
# after iteration 20
# iter    0   |   diff: 0.01506   |   V(start): 0.554
# N actions changed = 0
#
# after iteration 21
# iter    0   |   diff: 0.01430   |   V(start): 0.568
# N actions changed = 0
#
# after iteration 22
# iter    0   |   diff: 0.01359   |   V(start): 0.582
# N actions changed = 0
#
# after iteration 23
# iter    0   |   diff: 0.01291   |   V(start): 0.595
# N actions changed = 0
#
# after iteration 24
# iter    0   |   diff: 0.01226   |   V(start): 0.607
# N actions changed = 0
#
# after iteration 25
# iter    0   |   diff: 0.01165   |   V(start): 0.619
# N actions changed = 0
#
# after iteration 26
# iter    0   |   diff: 0.01107   |   V(start): 0.630
# N actions changed = 0
#
# after iteration 27
# iter    0   |   diff: 0.01051   |   V(start): 0.640
# N actions changed = 0
#
# after iteration 28
# iter    0   |   diff: 0.00999   |   V(start): 0.650
# N actions changed = 0
#
# after iteration 29
# iter    0   |   diff: 0.00949   |   V(start): 0.660
# N actions changed = 0
#
# after iteration 30
# iter    0   |   diff: 0.00901   |   V(start): 0.669
# N actions changed = 0
#
# after iteration 31
# iter    0   |   diff: 0.00856   |   V(start): 0.677
# N actions changed = 0
#
# after iteration 32
# iter    0   |   diff: 0.00814   |   V(start): 0.685
# N actions changed = 0
#
# after iteration 33
# iter    0   |   diff: 0.00773   |   V(start): 0.693
# N actions changed = 0
#
# after iteration 34
# iter    0   |   diff: 0.00734   |   V(start): 0.700
# N actions changed = 0
#
# after iteration 35
# iter    0   |   diff: 0.00698   |   V(start): 0.707
# N actions changed = 0
#
# after iteration 36
# iter    0   |   diff: 0.00663   |   V(start): 0.714
# N actions changed = 0
#
# after iteration 37
# iter    0   |   diff: 0.00630   |   V(start): 0.720
# N actions changed = 0
#
# after iteration 38
# iter    0   |   diff: 0.00598   |   V(start): 0.726
# N actions changed = 0
#
# after iteration 39
# iter    0   |   diff: 0.00568   |   V(start): 0.732
# N actions changed = 0
#
# after iteration 40
# iter    0   |   diff: 0.00540   |   V(start): 0.737
# N actions changed = 0
#
# after iteration 41
# iter    0   |   diff: 0.00513   |   V(start): 0.743
# N actions changed = 0
#
# after iteration 42
# iter    0   |   diff: 0.00487   |   V(start): 0.747
# N actions changed = 0
#
# after iteration 43
# iter    0   |   diff: 0.00463   |   V(start): 0.752
# N actions changed = 0
#
# after iteration 44
# iter    0   |   diff: 0.00440   |   V(start): 0.756
# N actions changed = 0
#
# after iteration 45
# iter    0   |   diff: 0.00418   |   V(start): 0.761
# N actions changed = 0
#
# after iteration 46
# iter    0   |   diff: 0.00397   |   V(start): 0.765
# N actions changed = 0
#
# after iteration 47
# iter    0   |   diff: 0.00377   |   V(start): 0.768
# N actions changed = 0
#
# after iteration 48
# iter    0   |   diff: 0.00358   |   V(start): 0.772
# N actions changed = 0
#
# after iteration 49
# iter    0   |   diff: 0.00340   |   V(start): 0.775
# N actions changed = 0
#
# after iteration 50
# iter    0   |   diff: 0.00323   |   V(start): 0.779
# N actions changed = 0
#
# after iteration 51
# iter    0   |   diff: 0.00307   |   V(start): 0.782
# N actions changed = 0
#
# after iteration 52
# iter    0   |   diff: 0.00292   |   V(start): 0.785
# N actions changed = 0
#
# after iteration 53
# iter    0   |   diff: 0.00277   |   V(start): 0.787
# N actions changed = 0
#
# after iteration 54
# iter    0   |   diff: 0.00263   |   V(start): 0.790
# N actions changed = 0
#
# after iteration 55
# iter    0   |   diff: 0.00250   |   V(start): 0.792
# N actions changed = 0
#
# after iteration 56
# iter    0   |   diff: 0.00238   |   V(start): 0.795
# N actions changed = 0
#
# after iteration 57
# iter    0   |   diff: 0.00226   |   V(start): 0.797
# N actions changed = 0
#
# after iteration 58
# iter    0   |   diff: 0.00214   |   V(start): 0.799
# N actions changed = 0
#
# after iteration 59
# iter    0   |   diff: 0.00204   |   V(start): 0.801
# N actions changed = 1
#
# non zero

# %%
if has_graphviz:
    from mdp import plot_graph, plot_graph_with_state_values, plot_graph_optimal_strategy_and_state_values
    display(plot_graph(mdp))

# %%
if has_graphviz:
    display(plot_graph_optimal_strategy_and_state_values(mdp, state_values, get_action_value))

# %% [markdown]
# ### Value iteration convervence proof (1 pts)
# **Note:** Assume that $\mathcal{S}, \mathcal{A}$ are finite.
#
# Update of value function in value iteration can be rewritten in a form of Bellman operator:
#
# $$(TV)(s) = \max_{a \in \mathcal{A}}\mathbb{E}\left[ r_{t+1} + \gamma V(s_{t+1}) | s_t = s, a_t = a\right]$$
#
# Value iteration algorithm with Bellman operator:
#
# ---
# &nbsp;&nbsp; Initialize $V_0$
#
# &nbsp;&nbsp; **for** $k = 0,1,2,...$ **do**
#
# &nbsp;&nbsp;&nbsp;&nbsp; $V_{k+1} \leftarrow TV_k$
#
# &nbsp;&nbsp;**end for**
#
# ---
#
# In [lecture](https://docs.google.com/presentation/d/1lz2oIUTvd2MHWKEQSH8hquS66oe4MZ_eRvVViZs2uuE/edit#slide=id.g4fd6bae29e_2_4) we established contraction property of bellman operator:
#
# $$
# ||TV - TU||_{\infty} \le \gamma ||V - U||_{\infty}
# $$
#
# For all $V, U$
#
# Using contraction property of Bellman operator, Banach fixed-point theorem and Bellman equations prove that value function converges to $V^*$ in value iterateion$
#
# *<-- Your proof here -->*
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Asynchronious value iteration (2 pts)
#
# Consider the following algorithm:
#
# ---
#
# Initialize $V_0$
#
# **for** $k = 0,1,2,...$ **do**
#
# &nbsp;&nbsp;&nbsp;&nbsp; Select some state $s_k \in \mathcal{S}$
#
# &nbsp;&nbsp;&nbsp;&nbsp; $V(s_k) := (TV)(s_k)$
#
# **end for**
#
# ---
#
#
# Note that unlike common value iteration, here we update only a single state at a time.
#
# **Homework.** Prove the following proposition:
#
# If for all $s \in \mathcal{S}$, $s$ appears in the sequence $(s_0, s_1, ...)$ infinitely often, then $V$ converges to $V*$
#
# *<-- Your proof here -->*

# %% [markdown]
# # HW Part 2: Policy iteration
#
# ## Policy iteration implementateion (3 pts)
#
# Let's implement exact policy iteration (PI), which has the following pseudocode:
#
# ---
# Initialize $\pi_0$   `// random or fixed action`
#
# For $n=0, 1, 2, \dots$
# - Compute the state-value function $V^{\pi_{n}}$
# - Using $V^{\pi_{n}}$, compute the state-action-value function $Q^{\pi_{n}}$
# - Compute new policy $\pi_{n+1}(s) = \operatorname*{argmax}_a Q^{\pi_{n}}(s,a)$
# ---
#
# Unlike VI, policy iteration has to maintain a policy - chosen actions from all states - and estimate $V^{\pi_{n}}$ based on this policy. It only changes policy once values converged.
#
#
# Below are a few helpers that you may or may not use in your implementation.

# %%
transition_probs = {
    's0': {
        'a0': {'s0': 0.5, 's2': 0.5},
        'a1': {'s2': 1}
    },
    's1': {
        'a0': {'s0': 0.7, 's1': 0.1, 's2': 0.2},
        'a1': {'s1': 0.95, 's2': 0.05}
    },
    's2': {
        'a0': {'s0': 0.4, 's1': 0.6},
        'a1': {'s0': 0.3, 's1': 0.3, 's2': 0.4}
    }
}
rewards = {
    's1': {'a0': {'s0': +5}},
    's2': {'a1': {'s0': -1}}
}

from mdp import MDP
mdp = MDP(transition_probs, rewards, initial_state='s0')

# %% [markdown]
# Let's write a function called `compute_vpi` that computes the state-value function $V^{\pi}$ for an arbitrary policy $\pi$.
#
# Unlike VI, this time you must find the exact solution, not just a single iteration.
#
# Recall that $V^{\pi}$ satisfies the following linear equation:
# $$V^{\pi}(s) = \sum_{s'} P(s,\pi(s),s')[ R(s,\pi(s),s') + \gamma V^{\pi}(s')]$$
#
# You'll have to solve a linear system in your code. (Find an exact solution, e.g., with `np.linalg.solve`.)

# %%
def compute_vpi(mdp, policy, gamma):
    """
    Computes V^pi(s) FOR ALL STATES under given policy.
    :param policy: a dict of currently chosen actions {s : a}
    :returns: a dict {state : V^pi(state) for all states}
    """
    
    states = sorted(mdp.get_all_states())
    n = len(states)

    p_policy = np.zeros(shape=(n, n))
    r_policy = np.zeros(n)

    for i, s in enumerate(states):
        a = policy[s]
        if a is None:
            p_policy[i, i] = 1.0
            r_policy[i] = 0.0
        else:
            for j, s_next in enumerate(states):
                prob = mdp.get_transition_prob(s, a, s_next)
                p_policy[i, j] = prob

                reward = mdp.get_reward(s, a, s_next)
                r_policy[i] += prob * reward

    I = np.eye(n)
    A = I - gamma * p_policy
    b = r_policy
    
    V = np.linalg.solve(A, b)

    return {s: V[i] for i, s in enumerate(states)}

# %%
test_policy = {s: np.random.choice(
    mdp.get_possible_actions(s)) for s in mdp.get_all_states()}
new_vpi = compute_vpi(mdp, test_policy, gamma)

print(new_vpi)

assert type(
    new_vpi) is dict, "compute_vpi must return a dict {state : V^pi(state) for all states}"
# Out:
# {'s0': np.float64(8.424074017527248), 's1': np.float64(11.919142569238751), 's2': np.float64(8.86744633423921)}

# %% [markdown]
# Once we've got new state values, it's time to update our policy.

# %%
def compute_new_policy(mdp, vpi, gamma):
    """
    Computes new policy as argmax of state values
    :param vpi: a dict {state : V^pi(state) for all states}
    :returns: a dict {state : optimal action for all states}
    """
    
    # print(vpi)

    new_policy = {}

    for state in mdp.get_all_states():

        if mdp.is_terminal(state):
            new_policy[state] = None
        else:
            possible_actions = mdp.get_possible_actions(state)

            q_values = [get_action_value(mdp, vpi, state, action, gamma) for action in possible_actions]

            new_policy[state] = possible_actions[np.argmax(q_values)]
    
    return new_policy

# %%
new_policy = compute_new_policy(mdp, new_vpi, gamma)

print(new_policy)

assert type(
    new_policy) is dict, "compute_new_policy must return a dict {state : optimal action for all states}"
# Out:
# {'s0': 'a1', 's1': 'a0', 's2': 'a1'}

# %% [markdown]
# __Main loop__

# %%
def policy_iteration(mdp, policy=None, gamma=0.9, num_iter=1000, min_difference=1e-5):
    """ 
    Run the policy iteration loop for num_iter iterations or till difference between V(s) is below min_difference.
    If policy is not given, initialize it at random.
    """

    states = mdp.get_all_states()

    count_of_states = len(states)

    if (policy == None):
        policy = {}
        for state in states:
            if mdp.is_terminal(state):
                policy[state] = None
            else:
                policy[state] = np.random.choice(mdp.get_possible_actions(state))

    # print(policy)

    vpi = {s: 0.0 for s in mdp.get_all_states()}

    for iter in range(0, num_iter):

        new_vpi = compute_vpi(mdp, policy, gamma)

        if max(abs(vpi[states[i]] - new_vpi[states[i]]) for i in range(0, count_of_states)) < min_difference:
            vpi = new_vpi
            break

        vpi = new_vpi

        policy = compute_new_policy(mdp, new_vpi, gamma)

    return state_values, policy

# %% [markdown]
# __Your PI Results__

# %%
# <YOUR CODE: compare PI and VI on the MDP from bonus 1, then on small & large FrozenLake>

transition_probs = {
    's0': {
        'a0': {'s0': 0.5, 's2': 0.5},
        'a1': {'s2': 1}
    },
    's1': {
        'a0': {'s0': 0.7, 's1': 0.1, 's2': 0.2},
        'a1': {'s1': 0.95, 's2': 0.05}
    },
    's2': {
        'a0': {'s0': 0.4, 's2': 0.6},
        'a1': {'s0': 0.3, 's1': 0.3, 's2': 0.4}
    }
}
rewards = {
    's1': {'a0': {'s0': +5}},
    's2': {'a1': {'s0': -1}}
}

from mdp import MDP
mdp_bonus = MDP(transition_probs, rewards, initial_state='s0')
mdp_frozen_small = FrozenLakeEnv(map_name='4x4', slip_chance=0.1)
mdp_frozen_large = FrozenLakeEnv(map_name='8x8', slip_chance=0.1)

# %%
def vi_learning(mdp, gamma):

    state_values = value_iteration(mdp, gamma=gamma)
    total_rewards = []

    for _ in range(1000):
        
        s = mdp.reset()
        rewards = []
        
        for __ in range(100):
        
            s, r, done, ___ = mdp.step(get_optimal_action(mdp, state_values, s, gamma))
        
            rewards.append(r)
        
            if done:
                break
        
        total_rewards.append(np.sum(rewards))

    return total_rewards

def pi_learning(mdp, gamma):
    
    state_values, policy = policy_iteration(mdp, gamma=gamma)
    total_rewards = []

    for _ in range(1000):
    
        s = mdp.reset()
        rewards = []
    
        for __ in range(100):
            
            a = policy.get(s)
            s, r, done, ___ = mdp.step(a)
            rewards.append(r)
            
            if done:
                break

        total_rewards.append(np.sum(rewards))

    return total_rewards

def comparator_vi_pi(mdp, gamma):

    reward_vi = np.mean(vi_learning(mdp, gamma))
    reward_pi = np.mean(pi_learning(mdp, gamma))

    return reward_vi, reward_pi

# %%
def draw_compare_plot(vi_value, pi_value):
    x_pos = [0, 5]
    values = [vi_value, pi_value]
    width = 3

    bars = plt.bar(x_pos, values, width, tick_label=['VI', 'PI'])

    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height + 0.01,
                f'{height}', ha='center', va='bottom')

    plt.show()

# %%
vi_reward, pi_reward = comparator_vi_pi(mdp_bonus, 0.95)

draw_compare_plot(vi_reward, pi_reward)
# Out:
# iter    0   |   diff: 3.50000   |   V(start): 0.000
# iter    1   |   diff: 0.69750   |   V(start): 0.000
# iter    2   |   diff: 0.66262   |   V(start): 0.663
# iter    3   |   diff: 0.52460   |   V(start): 1.004
# iter    4   |   diff: 0.38842   |   V(start): 1.358
# iter    5   |   diff: 0.36900   |   V(start): 1.727
# iter    6   |   diff: 0.34392   |   V(start): 2.057
# iter    7   |   diff: 0.31932   |   V(start): 2.375
# iter    8   |   diff: 0.30335   |   V(start): 2.679
# iter    9   |   diff: 0.28781   |   V(start): 2.966
# iter   10   |   diff: 0.27297   |   V(start): 3.239
# iter   11   |   diff: 0.25932   |   V(start): 3.498
# iter   12   |   diff: 0.24634   |   V(start): 3.744
# iter   13   |   diff: 0.23400   |   V(start): 3.978
# iter   14   |   diff: 0.22230   |   V(start): 4.200
# iter   15   |   diff: 0.21118   |   V(start): 4.412
# iter   16   |   diff: 0.20062   |   V(start): 4.612
# iter   17   |   diff: 0.19059   |   V(start): 4.803
# iter   18   |   diff: 0.18106   |   V(start): 4.984
# iter   19   |   diff: 0.17201   |   V(start): 5.156
# iter   20   |   diff: 0.16341   |   V(start): 5.319
# iter   21   |   diff: 0.15524   |   V(start): 5.475
# iter   22   |   diff: 0.14748   |   V(start): 5.622
# iter   23   |   diff: 0.14010   |   V(start): 5.762
# iter   24   |   diff: 0.13310   |   V(start): 5.895
# iter   25   |   diff: 0.12644   |   V(start): 6.022
# iter   26   |   diff: 0.12012   |   V(start): 6.142
# iter   27   |   diff: 0.11411   |   V(start): 6.256
# iter   28   |   diff: 0.10841   |   V(start): 6.364
# iter   29   |   diff: 0.10299   |   V(start): 6.467
# iter   30   |   diff: 0.09784   |   V(start): 6.565
# iter   31   |   diff: 0.09295   |   V(start): 6.658
# iter   32   |   diff: 0.08830   |   V(start): 6.746
# iter   33   |   diff: 0.08388   |   V(start): 6.830
# iter   34   |   diff: 0.07969   |   V(start): 6.910
# iter   35   |   diff: 0.07571   |   V(start): 6.986
# iter   36   |   diff: 0.07192   |   V(start): 7.058
# iter   37   |   diff: 0.06832   |   V(start): 7.126
# iter   38   |   diff: 0.06491   |   V(start): 7.191
# iter   39   |   diff: 0.06166   |   V(start): 7.252
# iter   40   |   diff: 0.05858   |   V(start): 7.311
# iter   41   |   diff: 0.05565   |   V(start): 7.367
# iter   42   |   diff: 0.05287   |   V(start): 7.420
# iter   43   |   diff: 0.05022   |   V(start): 7.470
# iter   44   |   diff: 0.04771   |   V(start): 7.518
# iter   45   |   diff: 0.04533   |   V(start): 7.563
# iter   46   |   diff: 0.04306   |   V(start): 7.606
# iter   47   |   diff: 0.04091   |   V(start): 7.647
# iter   48   |   diff: 0.03886   |   V(start): 7.686
# iter   49   |   diff: 0.03692   |   V(start): 7.723
# iter   50   |   diff: 0.03507   |   V(start): 7.758
# iter   51   |   diff: 0.03332   |   V(start): 7.791
# iter   52   |   diff: 0.03165   |   V(start): 7.823
# iter   53   |   diff: 0.03007   |   V(start): 7.853
# iter   54   |   diff: 0.02857   |   V(start): 7.881
# iter   55   |   diff: 0.02714   |   V(start): 7.908
# iter   56   |   diff: 0.02578   |   V(start): 7.934
# iter   57   |   diff: 0.02449   |   V(start): 7.959
# iter   58   |   diff: 0.02327   |   V(start): 7.982
# iter   59   |   diff: 0.02211   |   V(start): 8.004
# iter   60   |   diff: 0.02100   |   V(start): 8.025
# iter   61   |   diff: 0.01995   |   V(start): 8.045
# iter   62   |   diff: 0.01895   |   V(start): 8.064
# iter   63   |   diff: 0.01800   |   V(start): 8.082
# iter   64   |   diff: 0.01710   |   V(start): 8.099
# iter   65   |   diff: 0.01625   |   V(start): 8.115
# iter   66   |   diff: 0.01544   |   V(start): 8.131
# iter   67   |   diff: 0.01466   |   V(start): 8.145
# iter   68   |   diff: 0.01393   |   V(start): 8.159
# iter   69   |   diff: 0.01324   |   V(start): 8.173
# iter   70   |   diff: 0.01257   |   V(start): 8.185
# iter   71   |   diff: 0.01194   |   V(start): 8.197
# iter   72   |   diff: 0.01135   |   V(start): 8.208
# iter   73   |   diff: 0.01078   |   V(start): 8.219
# iter   74   |   diff: 0.01024   |   V(start): 8.229
# iter   75   |   diff: 0.00973   |   V(start): 8.239
# iter   76   |   diff: 0.00924   |   V(start): 8.248
# iter   77   |   diff: 0.00878   |   V(start): 8.257
# iter   78   |   diff: 0.00834   |   V(start): 8.266
# iter   79   |   diff: 0.00792   |   V(start): 8.274
# iter   80   |   diff: 0.00753   |   V(start): 8.281
# iter   81   |   diff: 0.00715   |   V(start): 8.288
# iter   82   |   diff: 0.00679   |   V(start): 8.295
# iter   83   |   diff: 0.00645   |   V(start): 8.301
# iter   84   |   diff: 0.00613   |   V(start): 8.308
# iter   85   |   diff: 0.00583   |   V(start): 8.313
# iter   86   |   diff: 0.00553   |   V(start): 8.319
# iter   87   |   diff: 0.00526   |   V(start): 8.324
# iter   88   |   diff: 0.00499   |   V(start): 8.329
# iter   89   |   diff: 0.00474   |   V(start): 8.334
# iter   90   |   diff: 0.00451   |   V(start): 8.338
# iter   91   |   diff: 0.00428   |   V(start): 8.343
# iter   92   |   diff: 0.00407   |   V(start): 8.347
# iter   93   |   diff: 0.00386   |   V(start): 8.351
# iter   94   |   diff: 0.00367   |   V(start): 8.354
# iter   95   |   diff: 0.00349   |   V(start): 8.358
# iter   96   |   diff: 0.00331   |   V(start): 8.361
# iter   97   |   diff: 0.00315   |   V(start): 8.364
# iter   98   |   diff: 0.00299   |   V(start): 8.367
# iter   99   |   diff: 0.00284   |   V(start): 8.370
# iter  100   |   diff: 0.00270   |   V(start): 8.373
# iter  101   |   diff: 0.00256   |   V(start): 8.375
# iter  102   |   diff: 0.00244   |   V(start): 8.378
# iter  103   |   diff: 0.00231   |   V(start): 8.380
# iter  104   |   diff: 0.00220   |   V(start): 8.382
# iter  105   |   diff: 0.00209   |   V(start): 8.384
# iter  106   |   diff: 0.00198   |   V(start): 8.386
# iter  107   |   diff: 0.00188   |   V(start): 8.388
# iter  108   |   diff: 0.00179   |   V(start): 8.390
# iter  109   |   diff: 0.00170   |   V(start): 8.392
# iter  110   |   diff: 0.00162   |   V(start): 8.393
# iter  111   |   diff: 0.00154   |   V(start): 8.395
# iter  112   |   diff: 0.00146   |   V(start): 8.396
# iter  113   |   diff: 0.00139   |   V(start): 8.398
# iter  114   |   diff: 0.00132   |   V(start): 8.399
# iter  115   |   diff: 0.00125   |   V(start): 8.400
# iter  116   |   diff: 0.00119   |   V(start): 8.402
# iter  117   |   diff: 0.00113   |   V(start): 8.403
# iter  118   |   diff: 0.00107   |   V(start): 8.404
# iter  119   |   diff: 0.00102   |   V(start): 8.405
# iter  120   |   diff: 0.00097   |   V(start): 8.406
# iter  121   |   diff: 0.00092   |   V(start): 8.407
# iter  122   |   diff: 0.00087   |   V(start): 8.407
# iter  123   |   diff: 0.00083   |   V(start): 8.408
# iter  124   |   diff: 0.00079   |   V(start): 8.409
# iter  125   |   diff: 0.00075   |   V(start): 8.410
# iter  126   |   diff: 0.00071   |   V(start): 8.411
# iter  127   |   diff: 0.00068   |   V(start): 8.411
# iter  128   |   diff: 0.00064   |   V(start): 8.412
# iter  129   |   diff: 0.00061   |   V(start): 8.412
# iter  130   |   diff: 0.00058   |   V(start): 8.413
# iter  131   |   diff: 0.00055   |   V(start): 8.414
# iter  132   |   diff: 0.00052   |   V(start): 8.414
# iter  133   |   diff: 0.00050   |   V(start): 8.415
# iter  134   |   diff: 0.00047   |   V(start): 8.415
# iter  135   |   diff: 0.00045   |   V(start): 8.416
# iter  136   |   diff: 0.00043   |   V(start): 8.416
# iter  137   |   diff: 0.00040   |   V(start): 8.416
# iter  138   |   diff: 0.00038   |   V(start): 8.417
# iter  139   |   diff: 0.00037   |   V(start): 8.417
# iter  140   |   diff: 0.00035   |   V(start): 8.417
# iter  141   |   diff: 0.00033   |   V(start): 8.418
# iter  142   |   diff: 0.00031   |   V(start): 8.418
# iter  143   |   diff: 0.00030   |   V(start): 8.418
# iter  144   |   diff: 0.00028   |   V(start): 8.419
# iter  145   |   diff: 0.00027   |   V(start): 8.419
# iter  146   |   diff: 0.00025   |   V(start): 8.419
# iter  147   |   diff: 0.00024   |   V(start): 8.419
# iter  148   |   diff: 0.00023   |   V(start): 8.420
# iter  149   |   diff: 0.00022   |   V(start): 8.420
# iter  150   |   diff: 0.00021   |   V(start): 8.420
# iter  151   |   diff: 0.00020   |   V(start): 8.420
# iter  152   |   diff: 0.00019   |   V(start): 8.421
# iter  153   |   diff: 0.00018   |   V(start): 8.421
# iter  154   |   diff: 0.00017   |   V(start): 8.421
# iter  155   |   diff: 0.00016   |   V(start): 8.421
# iter  156   |   diff: 0.00015   |   V(start): 8.421
# iter  157   |   diff: 0.00015   |   V(start): 8.421
# iter  158   |   diff: 0.00014   |   V(start): 8.421
# iter  159   |   diff: 0.00013   |   V(start): 8.422
# iter  160   |   diff: 0.00012   |   V(start): 8.422
# iter  161   |   diff: 0.00012   |   V(start): 8.422
# iter  162   |   diff: 0.00011   |   V(start): 8.422
# iter  163   |   diff: 0.00011   |   V(start): 8.422
# iter  164   |   diff: 0.00010   |   V(start): 8.422
# iter  165   |   diff: 0.00010   |   V(start): 8.422
# iter  166   |   diff: 0.00009   |   V(start): 8.422
# iter  167   |   diff: 0.00009   |   V(start): 8.422
# iter  168   |   diff: 0.00008   |   V(start): 8.423
# iter  169   |   diff: 0.00008   |   V(start): 8.423
# iter  170   |   diff: 0.00007   |   V(start): 8.423
# iter  171   |   diff: 0.00007   |   V(start): 8.423
# iter  172   |   diff: 0.00007   |   V(start): 8.423
# iter  173   |   diff: 0.00006   |   V(start): 8.423
# iter  174   |   diff: 0.00006   |   V(start): 8.423
# iter  175   |   diff: 0.00006   |   V(start): 8.423
# iter  176   |   diff: 0.00005   |   V(start): 8.423
# iter  177   |   diff: 0.00005   |   V(start): 8.423
# iter  178   |   diff: 0.00005   |   V(start): 8.423
# iter  179   |   diff: 0.00005   |   V(start): 8.423
# iter  180   |   diff: 0.00004   |   V(start): 8.423
# iter  181   |   diff: 0.00004   |   V(start): 8.423
# iter  182   |   diff: 0.00004   |   V(start): 8.423
# iter  183   |   diff: 0.00004   |   V(start): 8.423
# iter  184   |   diff: 0.00004   |   V(start): 8.423
# iter  185   |   diff: 0.00003   |   V(start): 8.423
# iter  186   |   diff: 0.00003   |   V(start): 8.423
# iter  187   |   diff: 0.00003   |   V(start): 8.423
# iter  188   |   diff: 0.00003   |   V(start): 8.424
# iter  189   |   diff: 0.00003   |   V(start): 8.424
# iter  190   |   diff: 0.00003   |   V(start): 8.424
# iter  191   |   diff: 0.00003   |   V(start): 8.424
# iter  192   |   diff: 0.00002   |   V(start): 8.424
# iter  193   |   diff: 0.00002   |   V(start): 8.424
# iter  194   |   diff: 0.00002   |   V(start): 8.424
# iter  195   |   diff: 0.00002   |   V(start): 8.424
# iter  196   |   diff: 0.00002   |   V(start): 8.424
# iter  197   |   diff: 0.00002   |   V(start): 8.424
# iter  198   |   diff: 0.00002   |   V(start): 8.424
# iter  199   |   diff: 0.00002   |   V(start): 8.424
# iter  200   |   diff: 0.00002   |   V(start): 8.424
# iter  201   |   diff: 0.00002   |   V(start): 8.424
# iter  202   |   diff: 0.00001   |   V(start): 8.424
# iter  203   |   diff: 0.00001   |   V(start): 8.424
# iter  204   |   diff: 0.00001   |   V(start): 8.424
# iter  205   |   diff: 0.00001   |   V(start): 8.424
# iter  206   |   diff: 0.00001   |   V(start): 8.424
# iter  207   |   diff: 0.00001   |   V(start): 8.424
# iter  208   |   diff: 0.00001   |   V(start): 8.424
# iter  209   |   diff: 0.00001   |   V(start): 8.424
# iter  210   |   diff: 0.00001   |   V(start): 8.424

# %%
vi_reward, pi_reward = comparator_vi_pi(mdp_frozen_small, 0.95)

draw_compare_plot(vi_reward, pi_reward)
# Out:
# iter    0   |   diff: 0.90000   |   V(start): 0.000
# iter    1   |   diff: 0.76950   |   V(start): 0.000
# iter    2   |   diff: 0.69447   |   V(start): 0.000
# iter    3   |   diff: 0.59378   |   V(start): 0.000
# iter    4   |   diff: 0.50768   |   V(start): 0.000
# iter    5   |   diff: 0.45691   |   V(start): 0.457
# iter    6   |   diff: 0.09031   |   V(start): 0.542
# iter    7   |   diff: 0.08515   |   V(start): 0.627
# iter    8   |   diff: 0.01756   |   V(start): 0.644
# iter    9   |   diff: 0.01242   |   V(start): 0.657
# iter   10   |   diff: 0.00282   |   V(start): 0.660
# iter   11   |   diff: 0.00170   |   V(start): 0.661
# iter   12   |   diff: 0.00042   |   V(start): 0.662
# iter   13   |   diff: 0.00023   |   V(start): 0.662
# iter   14   |   diff: 0.00006   |   V(start): 0.662
# iter   15   |   diff: 0.00003   |   V(start): 0.662
# iter   16   |   diff: 0.00001   |   V(start): 0.662

# %%
vi_reward, pi_reward = comparator_vi_pi(mdp_frozen_large, 0.95)

draw_compare_plot(vi_reward, pi_reward)
# Out:
# iter    0   |   diff: 0.90000   |   V(start): 0.000
# iter    1   |   diff: 0.76950   |   V(start): 0.000
# iter    2   |   diff: 0.65792   |   V(start): 0.000
# iter    3   |   diff: 0.56252   |   V(start): 0.000
# iter    4   |   diff: 0.50768   |   V(start): 0.000
# iter    5   |   diff: 0.45691   |   V(start): 0.000
# iter    6   |   diff: 0.41019   |   V(start): 0.000
# iter    7   |   diff: 0.36927   |   V(start): 0.000
# iter    8   |   diff: 0.33318   |   V(start): 0.000
# iter    9   |   diff: 0.30066   |   V(start): 0.000
# iter   10   |   diff: 0.27057   |   V(start): 0.000
# iter   11   |   diff: 0.24343   |   V(start): 0.000
# iter   12   |   diff: 0.21897   |   V(start): 0.000
# iter   13   |   diff: 0.19694   |   V(start): 0.197
# iter   14   |   diff: 0.10173   |   V(start): 0.285
# iter   15   |   diff: 0.07828   |   V(start): 0.363
# iter   16   |   diff: 0.03081   |   V(start): 0.394
# iter   17   |   diff: 0.02269   |   V(start): 0.412
# iter   18   |   diff: 0.00783   |   V(start): 0.419
# iter   19   |   diff: 0.00673   |   V(start): 0.423
# iter   20   |   diff: 0.00281   |   V(start): 0.424
# iter   21   |   diff: 0.00168   |   V(start): 0.425
# iter   22   |   diff: 0.00096   |   V(start): 0.425
# iter   23   |   diff: 0.00083   |   V(start): 0.426
# iter   24   |   diff: 0.00034   |   V(start): 0.426
# iter   25   |   diff: 0.00023   |   V(start): 0.426
# iter   26   |   diff: 0.00009   |   V(start): 0.426
# iter   27   |   diff: 0.00005   |   V(start): 0.426
# iter   28   |   diff: 0.00002   |   V(start): 0.426
# iter   29   |   diff: 0.00001   |   V(start): 0.426
# iter   30   |   diff: 0.00000   |   V(start): 0.426

# %% [markdown]
# ## Policy iteration convergence (3 pts)
#
# **Note:** Assume that $\mathcal{S}, \mathcal{A}$ are finite.
#
# We can define another Bellman operator:
#
# $$(T_{\pi}V)(s) = \mathbb{E}_{r, s'|s, a = \pi(s)}\left[r + \gamma V(s')\right]$$
#
# And rewrite policy iteration algorithm in operator form:
#
#
# ---
#
# Initialize $\pi_0$
#
# **for** $k = 0,1,2,...$ **do**
#
# &nbsp;&nbsp;&nbsp;&nbsp; Solve $V_k = T_{\pi_k}V_k$
#
# &nbsp;&nbsp;&nbsp;&nbsp; Select $\pi_{k+1}$ s.t. $T_{\pi_{k+1}}V_k = TV_k$
#
# **end for**
#
# ---
#
# To prove convergence of the algorithm we need to prove two properties: contraction an monotonicity.
#
# #### Monotonicity (0.5 pts)
#
# For all $V, U$ if $V(s) \le U(s)$   $\forall s \in \mathcal{S}$ then $(T_\pi V)(s) \le (T_\pi U)(s)$   $\forall s \in  \mathcal{S}$
#
# *<-- Your proof here -->*
#
# ![image.png](attachment:image.png)
#
# #### Contraction (1 pts)
#
# $$
# ||T_\pi V - T_\pi U||_{\infty} \le \gamma ||V - U||_{\infty}
# $$
#
# For all $V, U$
#
# *<-- Your proof here -->*
#
# ![image-2.png](attachment:image-2.png)
#
# #### Convergence (1.5 pts)
#
# Prove that there exists iteration $k_0$ such that $\pi_k = \pi^*$ for all $k \ge k_0$
#
# *<-- Your proof here -->*
